# %%
import pandas as pd
# Out:
# /Users/lucaswiman/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
nyt_county_covid_df = pd.read_csv('./covid-19-data/us-counties.csv')

# %%
county_field = nyt_county_covid_df.county
state_field = nyt_county_covid_df.state

# %%
alameda_county_stats = nyt_county_covid_df[county_field == 'Alameda'][state_field == 'California']
# Out:
# /Users/lucaswiman/.pyenv/versions/3.7.6/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
alameda_county_stats
# Out:
#              date   county       state    fips  cases  deaths
# 399    2020-03-01  Alameda  California  6001.0      1       0
# 426    2020-03-02  Alameda  California  6001.0      1       0
# 459    2020-03-03  Alameda  California  6001.0      2       0
# 494    2020-03-04  Alameda  California  6001.0      2       0
# 533    2020-03-05  Alameda  California  6001.0      2       0
# 583    2020-03-06  Alameda  California  6001.0      3       0
# 657    2020-03-07  Alameda  California  6001.0      3       0
# 752    2020-03-08  Alameda  California  6001.0      3       0
# 866    2020-03-09  Alameda  California  6001.0     24       0
# 998    2020-03-10  Alameda  California  6001.0     25       0
# 1164   2020-03-11  Alameda  California  6001.0     25       0
# 1370   2020-03-12  Alameda  California  6001.0     29       0
# 1630   2020-03-13  Alameda  California  6001.0     29       0
# 1947   2020-03-14  Alameda  California  6001.0     29       0
# ...

# %%
alameda_county_stats.plot(x='date', y='cases', style='o', logy=True)
alameda_county_stats.plot(x='date', y='cases', style='o')
